# %% [markdown]
# # Exam Template
#
# **Instructions:**
# - Do not add extra print statements
# - Do not change function names or signatures
# - Write your code only where indicated
# - Return values exactly as specified

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
# Do NOT add additional imports

# %% [markdown]
# ## Problem 1: Markov Chains

# %%
# 1.1 Transition Matrix
def comp_transition_matrix(transitions, n_states):
    """
    Parameters:
        transitions : np.ndarray of shape (n, 2)
        n_states : int
    Returns:
        P : np.ndarray of shape (n_states, n_states)
    """
    # YOUR CODE HERE
    pass

# %%
# 1.2 Stationary Distribution
def stationary_distribution(P):
    """
    Parameters:
        P : np.ndarray
    Returns:
        pi : np.ndarray
    """
    # YOUR CODE HERE
    pass

# %% [markdown]
# ## Problem 2: Classification & Cost

# %%
def train_logistic_regression(X_train, y_train):
    """
    Returns a trained LogisticRegression model
    """
    # YOUR CODE HERE
    pass

# %%
def compute_cost(y_true, y_pred):
    """
    Returns scalar cost
    """
    # YOUR CODE HERE
    pass

# %% [markdown]
# ## Problem 3: Confidence Intervals

# %%
def per_observation_cost(y_true, y_pred):
    """
    Returns cost per observation
    """
    # YOUR CODE HERE
    pass

# %%
def confidence_interval(costs, alpha=0.05):
    """
    Returns (lower, upper) confidence interval
    """
    # YOUR CODE HERE
    pass
